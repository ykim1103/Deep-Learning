# %% [markdown]
# <a href="https://colab.research.google.com/github/ykim1103/Deep-Learning/blob/master/%5B%EC%BD%94%EB%93%9C_4_1a%5D_BP_mnist_EarlyStop_2024_%EB%B0%A9%ED%86%B5%EB%8C%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [1] 필요한 패키지 불러오기

# %%
import matplotlib.pyplot as plt
from tensorflow.keras import datasets
from tensorflow.keras import Sequential, optimizers, callbacks
from tensorflow.keras.layers import Flatten, Dense

# %% [markdown]
# [2] 정확도 및 손실함수 시각화 함수 정의

# %%
def plot_metric(h, metric):
    train_history = h.history[metric]
    val_history = h.history['val_'+metric]
    epochs = range(1, len(train_history) + 1)
    plt.plot(epochs, train_history)
    plt.plot(epochs, val_history)
    plt.legend(['training '+metric, 'validation '+metric])
    plt.title('Training and validation ' + metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.show()

# %% [markdown]
# [3] MNIST 데이터 로드 및 정규화

# %%
# MNIST 데이터베이스에서 훈련용 및 평가용 이미지와 레이블 로드
(train_imgs, train_labels), (test_imgs, test_labels) = \
                                         datasets.mnist.load_data()
# 픽셀 값을 0~1 사이로 정규화
train_imgs, test_imgs = train_imgs / 255.0, test_imgs / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %% [markdown]
# [4] 2층 피드포워드 네트워크 구성

# %%
# 모델 구성 후 요약 정보 출력
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='sigmoid'),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# [5] 모델 컴파일

# %%
# 모델 컴파일
model.compile(optimizer=optimizers.SGD(0.1, momentum=0.9),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# [6] 모델 학습

# %%
early_stop = callbacks.EarlyStopping(monitor='val_loss',
                                        min_delta=0,
                                        patience=10,
                                        verbose=1,
                                        restore_best_weights=True)

hist = model.fit(train_imgs, train_labels, epochs=50,
                   callbacks=[early_stop], validation_split=0.2)
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 12s 4ms/step - loss: 0.3095 - accuracy: 0.9051 - val_loss: 0.1668 - val_accuracy: 0.9510
# Epoch 2/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1337 - accuracy: 0.9607 - val_loss: 0.1270 - val_accuracy: 0.9628
# Epoch 3/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0923 - accuracy: 0.9727 - val_loss: 0.1232 - val_accuracy: 0.9625
# Epoch 4/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0695 - accuracy: 0.9792 - val_loss: 0.0948 - val_accuracy: 0.9717
# Epoch 5/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0534 - accuracy: 0.9844 - val_loss: 0.0941 - val_accuracy: 0.9716
# Epoch 6/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0424 - accuracy: 0.9879 - val_loss: 0.0895 - val_accuracy: 0.9722
# Epoch 7/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0341 - accuracy: 0.9901 - val_loss: 0.0783 - val_accuracy: 0.9759
# Epoch 8/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0278 - accuracy: 0.9922 - val_loss: 0.0771 - val_accuracy: 0.9768
# Epoch 9/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0215 - accuracy: 0.9949 - val_loss: 0.0807 - val_accuracy: 0.9766
# Epoch 10/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0171 - accuracy: 0.9963 - val_loss: 0.0791 - val_accuracy: 0.9765
# Epoch 11/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0135 - accuracy: 0.9976 - val_loss: 0.0759 - val_accuracy: 0.9785
# Epoch 12/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0105 - accuracy: 0.9987 - val_loss: 0.0769 - val_accuracy: 0.9787
# Epoch 13/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.0797 - val_accuracy: 0.9772
# Epoch 14/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0071 - accuracy: 0.9995 - val_loss: 0.0751 - val_accuracy: 0.9788
# Epoch 15/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.0763 - val_accuracy: 0.9778
# Epoch 16/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0049 - accuracy: 0.9998 - val_loss: 0.0768 - val_accuracy: 0.9783
# Epoch 17/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0044 - accuracy: 0.9999 - val_loss: 0.0765 - val_accuracy: 0.9783
# Epoch 18/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0039 - accuracy: 0.9999 - val_loss: 0.0763 - val_accuracy: 0.9785
# Epoch 19/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9787
# Epoch 20/50
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9790
# Epoch 21/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9790
# Epoch 22/50
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9793
# Epoch 23/50
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9783
# Epoch 24/50
# 1487/1500 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 14.
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9790
# Epoch 24: early stopping

# %% [markdown]
# [7] 모델의 손실함수 및 정확도 시각화

# %%
plot_metric(hist, 'accuracy')
plot_metric(hist, 'loss')

# %% [markdown]
# [8] 훈련용 집합 및 검증용 집합에 대한 인식률 출력

# %%
# 훈련 집합을 대상으로 평가
_, train_acc = model.evaluate(train_imgs, train_labels)
print('훈련 데이터 인식률 = ', train_acc)

# 테스트 집합을 대상으로 평가
_, test_acc = model.evaluate(test_imgs, test_labels)
print('테스트 데이터 인식률 = ', test_acc)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0191 - accuracy: 0.9956
# 훈련 데이터 인식률 =  0.9956333041191101
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0704 - accuracy: 0.9772
# 테스트 데이터 인식률 =  0.9771999716758728
